# %% [markdown]
# # **Lab 3.2 Gradient Boost Mask**

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from mpl_toolkits.axes_grid1 import ImageGrid
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# %% [markdown]
# Read an image using OpenCV (Use your own image).

# %%
### START CODE HERE ###

img = cv2.imread(None)

### END CODE HERE ###
plt.imshow(img,cmap='gray')

# %% [markdown]
# ## **Unsharp Masking using image gradient from differntial kernel**

# %% [markdown]
# Resource : https://www.notion.so/Image-Contrast-Enhancement-Unsharp-masking-0d1683a1d3c742f69a4c0835141941a7
#
# In this lab you can use signal.convolve2d() to perform the 2D convolution.
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - In this lab, you can use `signal.convolve2d()` to perform 2D convolution.
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###

lpc_mask = None
                    
k = None

grad = signal.convolve2d(None)

### END CODE HERE ###

# %% [markdown]
# Now, let's try with k value in range `[0.1,0.2,0.3,0.4,...,1.0]`. Then, display the result using `animation.FuncAnimation()` like the reference image below.
#
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![Recording2024-04-16125002-ezgif.com-video-to-gif-converter.gif](attachment:Recording2024-04-16125002-ezgif.com-video-to-gif-converter.gif)
#
# </details>

# %%
# %%capture
### START CODE HERE ###
lpc_mask = None
k = None

fig, axs = plt.subplots(1, 3, figsize=(10, 5))

def update(frame):
    pass

### END CODE HERE ###
ani =  animation.FuncAnimation(fig, update, frames=len(k), interval=200, blit=False)

# %%
display(HTML(ani.to_jshtml()))

# %% [markdown]
# ## **Unsharp Masking using image gradient from image difference**

# %% [markdown]
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###

lpc_mask = None
                    
k = None

grad = signal.convolve2d(None)

### END CODE HERE ###

# %% [markdown]
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![Recording2024-04-16125734-ezgif.com-video-to-gif-converter.gif](attachment:Recording2024-04-16125734-ezgif.com-video-to-gif-converter.gif)
#
# </details>

# %%
# %%capture
### START CODE HERE ###
lpc_mask = None
k = None

fig, axs = plt.subplots(1, 3, figsize=(10, 5))

def update(frame):
    pass

### END CODE HERE ###
ani =  animation.FuncAnimation(fig, update, frames=len(k), interval=200, blit=False)

# %%
display(HTML(ani.to_jshtml()))

# %% [markdown]
# Now, Let's try with noisy image
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
noisy_img = None

### END CODE HERE ###
plt.imshow(noisy_img, cmap='gray')
plt.title('Noisy Image')
plt.show()

# %% [markdown]
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###

lpc_mask = None
                    
k = None

grad = signal.convolve2d(None)

### END CODE HERE ###

# %% [markdown]
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###

lpc_mask = None
                    
k = None

grad = signal.convolve2d(None)

### END CODE HERE ###

# %% [markdown]
# Questions:
# 1. How would noise affect the image resulted from the unsharp masking from differential kernel vs from image difference?
# 2. Discuss processing time difference between conventional three steps (straight forward) unsharp masking and integral kernel (integration of three steps into a single kernel).

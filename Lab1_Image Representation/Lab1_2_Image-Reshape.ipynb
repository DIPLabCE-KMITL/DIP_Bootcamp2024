# %% [markdown]
# # **Lab 1.2 Image Reshape**

# %% [markdown]
# In this lab, you will explore how memory changes when data types are converted from a list to a numpy array, image channel organization and batch organization.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')
import os

# %% [markdown]
# ## **How memory change due to converting datatype from list to numpy array**
#
# <summary>
# <font size="3" color="orange">
# <b>Memory Structure of data object</b>
# </font>
# </summary>
#
# ![image.png](attachment:image.png)

# %%
a = [1,2,3]
b = a

# %% [markdown]
# Show the memory address of list a, b using id().

# %%
## start your code

## end your code

# %% [markdown]
# If we modify an element of b[0], how would a be afftected?
# Show compare elements of list a, b before and after change b.

# %%
# start your code

# end your code

# %% [markdown]
# Create a new copy of list b assigned to list a.
# Show memory address of new b compared to a

# %%
# start your code

# end your code

# %% [markdown]
# Convert a python list to a numpy array. Show the difference of memory address and
# <br>stored data of object list a vs array b

# %%
# start your code

# end your code

# %% [markdown]
# Convert an array of a to a tensor and show tensor information such as stored data, data type,
# <br>memory address using data_ptr(), and running device using tensor device attribute

# %%
# Start your code

# End your code

# %% [markdown]
# ## **Channel Organization**

# %% [markdown]
# ### BGR (openCV) vs RGB (matplotlib)
# For OpenCV, images are read in BGR format, but Matplotlib uses RGB. Please use `cv2.imread()` `and plt.imread()`. Then, display the test images read by both tools.
#
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical.
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
# Start your code

# End your code

# %% [markdown]
# After reading the image using both tools, slice and plot each channel from each image.
#
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical.
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
# Start your code

# End your code

# %% [markdown]
# #### Convert OpenCV BGR ➡️ RGB
# Rearrange the channels of an image from OpenCV using `cv2.cvtColor(img, cv2.COLOR_BGR2RGB)`.Then, display the image
#
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical.
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
# Start your code

# End your code

# %% [markdown]
# ### Channel First vs Channel Last

# %% [markdown]
# Try using `np.transpose(img)`, `np.transpose(img,(2,0,1))`, `np.reshape(img,(3, 4, 4))`, and `np.moveaxis(img,-1,0)` to convert the image to a channel-first format (`[h,w,ch] -> [ch,h,w]`).

# %%
# Start your code

# End your code

# %% [markdown]
# #### `np.transpose(img)` & `np.transpose(img,(2,0,1))`
# You'll need to demonstrate(by printing the value) how the array arrangement and shape of the array change compared to the original one. Show an anmya

# %%
# Start your code

# End your code

# %% [markdown]
# #### `np.reshape(img,(3, 4, 4))`
# You'll need to demonstrate(by printing the value) how the array arrangement and shape of the array change compared to the original one.

# %%
# Start your code

# End your code

# %% [markdown]
# #### `np.moveaxis(img,-1,0)`
# You'll need to demonstrate(by printing the value) how the array arrangement and shape of the array change compared to the original one.

# %%
# Start your code

# End your code

# %% [markdown]
# Display the image from all operation like the reference image below.
#
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical.
#
# ![image-2.png](attachment:image-2.png)
#
# </details>

# %%
# Start your code

# End your code

# %% [markdown]
# ## **Batch Organization**

# %% [markdown]
# In this part, you'll learn the use of squeeze() and unsqueeze() in pytorch.
# - `squeeze()`<br/>
# Returns a tensor with all specified dimensions of `input` of size 1 removed.
# For example, if input is of shape: $(A×1×B×C×1×D)$ then the `input.squeeze()` will be of shape: $(A×B×C×D)$.
# When `dim` is given, a squeeze operation is done only in the given dimension(s). If input is of shape: $(A×1×B)$, `squeeze(input, 0)` leaves the tensor unchanged, but `squeeze(input, 1)` will squeeze the tensor to the shape $(A×B)$.
# - `unsqueeze()`<br/>
# Returns a new tensor with a dimension of size one inserted at the specified position.
# The returned tensor shares the same underlying data with this tensor.
# A `dim` value within the range `[-input.dim() - 1, input.dim() + 1)` can be used. Negative `dim` will correspond to `unsqueeze()` applied at `dim` = `dim + input.dim() + 1`.

# %%
import torch

# %% [markdown]
# Create a random tensor using `torch.randn(3, 4)`. Then, print the shape of the tensor.

# %%
# Start your code

# End your code

# %% [markdown]
# Try to do `unsqueeze()` with `dim = 1`. Then, print the value and shape of the tensor.

# %%
# Start your code

# End your code

# %% [markdown]
# From the cell above, try to squeeze the tensor using `squeeze()`. Then, print the value and shape of the tensor.

# %%
# Start your code

# End your code

# %% [markdown]
# Based on the cell above, try to use `unsqueeze()`, but change the `dim` value to something else. Then, print the value and shape of the tensor. After that, `squeeze()` the tensor and print the value and shape again.
# Please try using a dim value in the range [1,4].

# %%
# Start your code

# End your code

# %% [markdown]
# **Question**
# 1. How to perform manual color conversion (using only array slicing) of image array read from openCV (BGR) to RGB?
# 2. How to perform manual conversion (using only array slicing) of image array from channel last to channel first?
# 3. Arrange a Tensor Batch of Training images with batch size = 4 from numpy array dataset with shape (10,224,224,1)
